# %%
import numpy as np
import pandas as pd

# %%
#we have to write this "r" int the starting of the paranthesis......REMEMBER
train=np.genfromtxt(r"C:\Users\DEEPAK\Documents\ML_Codes\Diabetes\train.csv",delimiter= ",")
test=np.genfromtxt(r"C:\Users\DEEPAK\Documents\ML_Codes\Diabetes\test.csv",delimiter= ",")
train_data=pd.read_csv(r"C:\Users\DEEPAK\Documents\ML_Codes\Diabetes\train.csv")
test_data=pd.read_csv(r"C:\Users\DEEPAK\Documents\ML_Codes\Diabetes\test.csv")

# %%
train
# Out:
# array([[-4.91050164e-02, -4.46416365e-02,  1.60854917e-01, ...,
#          2.80165065e-02,  1.13486232e-02,  3.46000000e+02],
#        [-7.09002471e-02,  5.06801187e-02, -8.91974838e-02, ...,
#         -1.29079423e-02, -5.49250874e-02,  1.04000000e+02],
#        [ 1.75052192e-03, -4.46416365e-02, -7.08746786e-02, ...,
#         -2.25121719e-02,  7.20651633e-03,  4.90000000e+01],
#        ...,
#        [ 2.35457526e-02, -4.46416365e-02,  7.03187031e-02, ...,
#         -1.91970476e-02, -9.36191133e-03,  2.88000000e+02],
#        [ 1.62806757e-02,  5.06801187e-02,  7.24743273e-02, ...,
#         -2.36445576e-02,  6.10539062e-02,  1.31000000e+02],
#        [-9.14709343e-03,  5.06801187e-02, -3.09956318e-02, ...,
#          6.20931562e-03,  2.79170509e-02,  4.20000000e+01]])

# %%
train_data
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2    0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3    0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 5   -0.060003  0.050680 -0.047163 -0.022885 -0.071743 -0.057681 -0.006584
# 6   -0.074533  0.050680  0.055229 -0.040099  0.053469  0.053174 -0.043401
# 7   -0.016412 -0.044642 -0.013751  0.132044 -0.009825 -0.003819  0.019187
# 8    0.023546  0.050680 -0.020218 -0.036656 -0.013953 -0.015092  0.059685
# 9    0.074401 -0.044642  0.031517  0.101058  0.046589  0.036890  0.015505
# 10   0.030811 -0.044642 -0.033151 -0.022885 -0.046975 -0.081167  0.103865
# 11   0.005383 -0.044642 -0.048241 -0.012556  0.001183 -0.006637  0.063367
# ...

# %%
#doing by using NUMPY for easier operations
train.shape
Xnp=train[:,0:10]
Ynp=train[:,10:11]
Xnp.shape,Ynp.shape
Xnp_test=test
Xnp
# Out:
# array([[-0.04910502, -0.04464164,  0.16085492, ...,  0.03430886,
#          0.02801651,  0.01134862],
#        [-0.07090025,  0.05068012, -0.08919748, ..., -0.00259226,
#         -0.01290794, -0.05492509],
#        [ 0.00175052, -0.04464164, -0.07087468, ..., -0.03949338,
#         -0.02251217,  0.00720652],
#        ...,
#        [ 0.02354575, -0.04464164,  0.0703187 , ..., -0.00259226,
#         -0.01919705, -0.00936191],
#        [ 0.01628068,  0.05068012,  0.07247433, ..., -0.00259226,
#         -0.02364456,  0.06105391],
#        [-0.00914709,  0.05068012, -0.03099563, ..., -0.00259226,
#          0.00620932,  0.02791705]])

# %%
#now trying this using PANDAS....let's see if it works....
train_data.shape
Xpd=train_data.iloc[:,0:10]
Ypd=train_data.iloc[:,10:11]
Xpd_test=test
Xpd
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2    0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3    0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 5   -0.060003  0.050680 -0.047163 -0.022885 -0.071743 -0.057681 -0.006584
# 6   -0.074533  0.050680  0.055229 -0.040099  0.053469  0.053174 -0.043401
# 7   -0.016412 -0.044642 -0.013751  0.132044 -0.009825 -0.003819  0.019187
# 8    0.023546  0.050680 -0.020218 -0.036656 -0.013953 -0.015092  0.059685
# 9    0.074401 -0.044642  0.031517  0.101058  0.046589  0.036890  0.015505
# 10   0.030811 -0.044642 -0.033151 -0.022885 -0.046975 -0.081167  0.103865
# 11   0.005383 -0.044642 -0.048241 -0.012556  0.001183 -0.006637  0.063367
# ...

# %%
#from numpy
from sklearn import model_selection
xtrain_np, xtest_np, ytrain_np, ytest_np = model_selection.train_test_split(Xnp,Ynp)

# %%
xtrain_np
# Out:
# array([[ 0.0090156 , -0.04464164,  0.05522933, ...,  0.02323852,
#          0.05568355,  0.10661708],
#        [ 0.0090156 ,  0.05068012,  0.03043966, ...,  0.07120998,
#         -0.02364456,  0.01549073],
#        [ 0.04534098, -0.04464164,  0.03906215, ..., -0.01255556,
#          0.06432823,  0.0569118 ],
#        ...,
#        [-0.01641217, -0.04464164, -0.03530688, ..., -0.03949338,
#         -0.07020931, -0.07977773],
#        [-0.09269548, -0.04464164,  0.02828403, ..., -0.03949338,
#         -0.00514531, -0.0010777 ],
#        [ 0.03444337, -0.04464164, -0.03854032, ..., -0.00259226,
#          0.03119299,  0.09833287]])

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg1.fit(xtrain_np,ytrain_np)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
alg1.score(xtest_np,ytest_np)
# Out:
# 0.4253464963710517

# %%
#from pandas
from sklearn import model_selection
xtrain_pd, xtest_pd, ytrain_pd, ytest_pd = model_selection.train_test_split(Xpd,Ypd)

# %%
xtrain_pd
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 111 -0.056370 -0.044642 -0.074108 -0.050428 -0.024960 -0.047034  0.092820
# 276  0.038076  0.050680 -0.018062  0.066630 -0.051103 -0.016658 -0.076536
# 11   0.005383 -0.044642 -0.048241 -0.012556  0.001183 -0.006637  0.063367
# 194 -0.052738 -0.044642 -0.062252 -0.026328 -0.005697 -0.005072  0.030232
# 178  0.067136  0.050680 -0.029918  0.057449 -0.000193 -0.015719  0.074412
# 287  0.009016 -0.044642  0.014272  0.014987  0.054845  0.047224  0.070730
# 49   0.016281 -0.044642 -0.063330 -0.057314 -0.057983 -0.048912  0.008142
# 317  0.027178  0.050680  0.094031  0.097616 -0.034592 -0.032002 -0.043401
# 67   0.005383 -0.044642  0.059541 -0.056166  0.024574  0.052861 -0.043401
# 330 -0.009147  0.050680 -0.030996 -0.026328 -0.011201 -0.001001 -0.021311
# 163  0.067136  0.050680 -0.030996  0.004658  0.024574  0.035638 -0.028674
# 120  0.019913  0.050680  0.045529  0.029906 -0.062111 -0.055802 -0.072854
# ...

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg1.fit(xtrain_pd,ytrain_pd)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
alg1.score(xtest_pd,ytest_pd)
# Out:
# 0.5282576605048925

# %%
Y_pred = alg1.predict(Xnp_test)

# %%
Y = np.around(Y_pred,decimals=5)

# %%
np.savetxt("predict.csv",Y,delimiter=",")
